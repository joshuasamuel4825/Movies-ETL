# %%
import pandas as pd
from sqlalchemy import create_engine

# Dependencies and Setup FOR API
import numpy as np
import requests
import time
from datetime import datetime
import json

# Import API key
from api_keys import tmdb_api_key

# %% [markdown]
# ### Store CSV into DataFrame

# %%
disney_csv_file = "./Datasets/Disney_titles.csv"
disney_titles_df = pd.read_csv(disney_csv_file)
disney_titles_df.head()
# Out:
#         id                            title   type  \
# 0  tm74391                         Fantasia  MOVIE
# 1  tm67803  Snow White and the Seven Dwarfs  MOVIE
# 2  tm82546                        Pinocchio  MOVIE
# 3  tm79357                            Bambi  MOVIE
# 4  tm62671                  Treasure Island  MOVIE
#
#                                          description  release_year  \
# 0  Walt Disney's timeless masterpiece is an extra...          1940
# 1  A beautiful girl, Snow White, takes refuge in ...          1937
# 2  Lonely toymaker Geppetto has his wishes answer...          1940
# 3  Bambi's tale unfolds from season to season as ...          1942
# 4  Enchanted by the idea of locating treasure bur...          1950
#
#   age_certification  runtime  \
# 0                 G      120
# 1                 G       83
# 2                 G       88
# 3                 G       70
# 4                PG       96
#
#                                               genres production_countries  \
# 0        ['animation', 'family', 'music', 'fantasy']               ['US']
# 1  ['fantasy', 'family', 'romance', 'animation', ...               ['US']
# 2       ['animation', 'comedy', 'family', 'fantasy']               ['US']
# 3                   ['animation', 'drama', 'family']               ['US']
# 4                               ['family', 'action']         ['GB', 'US']
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0      NaN  tt0032455         7.7     94681.0           57.751         7.4
# 1      NaN  tt0029583         7.6    195321.0          107.137         7.1
# 2      NaN  tt0032910         7.5    141937.0           71.160         7.1
# 3      NaN  tt0034492         7.3    140406.0           68.136         7.0
# 4      NaN  tt0043067         6.9      8229.0           10.698         6.5

# %%
netflix_csv_file = "./Datasets/Netflix_titles.csv"
netflix_titles_df = pd.read_csv(netflix_csv_file)
netflix_titles_df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
# 4               NaN      150                            ['war', 'action']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# 2               ['US']      NaN  tt0068473         7.7    107673.0
# 3               ['GB']      NaN  tt0071853         8.2    534486.0
# 4         ['GB', 'US']      NaN  tt0061578         7.7     72662.0
#
#    tmdb_popularity  tmdb_score
# 0            0.600         NaN
# 1           40.965       8.179
# 2           10.010       7.300
# 3           15.461       7.811
# 4           20.398       7.600

# %% [markdown]
# ### Connect to local database

# %%
protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5432
database_name = 'Entertainment_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['disney', 'netflix', 'Disney', 'Netflix']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
disney_titles_df.to_sql(name='disney', con=engine, if_exists='append', index=False)

# %%
netflix_titles_df.to_sql(name='netflix', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the disney table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from disney', con=engine).head()

# %%
### Perform API Call
# URL for GET requests to retrieve popularity data
url = "https://api.themoviedb.org/3/movie/popular?page=1&api_key=" + tmdb_api_key
# print(url)

# Print the response object to the console
requests.get(url)

# Retreiving data and converting into JSON (Jsonify)
response = requests.get(url).json()

response
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/bQXAqRx2Fgc46uCVWgoPz5L5Dtr.jpg',
#    'genre_ids': [28, 14, 878],
#    'id': 436270,
#    'original_language': 'en',
#    'original_title': 'Black Adam',
#    'overview': 'Nearly 5,000 years after he was bestowed with the almighty powers of the Egyptian gods—and imprisoned just as quickly—Black Adam is freed from his earthly tomb, ready to unleash his unique form of justice on the modern world.',
#    'popularity': 8198.814,
#    'poster_path': '/pFlaoHTZeyNkG83vxsAJiGzfSsa.jpg',
#    'release_date': '2022-10-19',
#    'title': 'Black Adam',
#    'video': False,
#    'vote_average': 7.3,
#    'vote_count': 2493},
#   {'adult': False,
#    'backdrop_path': '/7zQJYV02yehWrQN6NjKsBorqUUS.jpg',
#    'genre_ids': [28, 18, 36],
#    'id': 724495,
#    'original_language': 'en',
#    'original_title': 'The Woman King',
#    'overview': 'The story of the Agojie, the all-female unit of warriors who protected the African Kingdom of Dahomey in the 1800s with skills and a fierceness unlike anything the world has ever seen, and General Nanisca as she trains the next generation of recruits and readies them for battle against an enemy determined to destroy their way of life.',
#    'popularity': 4662.739,
#    'poster_path': '/438QXt1E3WJWb3PqNniK0tAE5c1.jpg',
#    'release_date': '2022-09-15',
#    'title': 'The Woman King',
#    'video': False,
#    'vote_average': 7.9,
#    'vote_count': 611},
#   {'adult': False,
#    'backdrop_path': '/au4HUSWDRadIcl9CqySlw1kJMfo.jpg',
#    'genre_ids': [80, 28, 53],
#    'id': 829799,
#    'original_language': 'en',
#    'original_title': 'Paradise City',
#    'overview': 'Renegade bounty hunter Ryan Swan must carve his way through the Hawaiian crime world to wreak vengeance on the kingpin who murdered his father.',
#    'popularity': 2645.37,
#    'poster_path': '/xdmmd437QdjcCls8yCQxrH5YYM4.jpg',
#    'release_date': '2022-11-11',
#    'title': 'Paradise City',
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 40},
#   {'adult': False,
#    'backdrop_path': '/sUuzl04qNIYsnwCLQpZ2RSvXA1V.jpg',
#    'genre_ids': [35, 28, 53],
#    'id': 792775,
#    'original_language': 'is',
#    'original_title': 'Leynilögga',
#    'overview': "When Bússi, Iceland's toughest cop, is forced to work with a new partner to solve a series of bank robberies, the pressure to close the case as soon as possible proves too much for him.",
#    'popularity': 2308.284,
#    'poster_path': '/jnWyZsaCl3Ke6u6ReSmBRO8S1rX.jpg',
#    'release_date': '2022-05-23',
#    'title': 'Cop Secret',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 33},
#   {'adult': False,
#    'backdrop_path': '/kmzppWh7ljL6K9fXW72bPN3gKwu.jpg',
#    'genre_ids': [14, 28, 35, 80],
#    'id': 1013860,
#    'original_language': 'en',
#    'original_title': 'R.I.P.D. 2: Rise of the Damned',
#    'overview': 'When Sheriff Roy Pulsipher finds himself in the afterlife, he joins a special police force and returns to Earth to save humanity from the undead.',
#    'popularity': 2530.159,
#    'poster_path': '/g4yJTzMtOBUTAR2Qnmj8TYIcFVq.jpg',
#    'release_date': '2022-11-15',
#    'title': 'R.I.P.D. 2: Rise of the Damned',
#    'video': False,
#    'vote_average': 6.7,
#    'vote_count': 206},
#   {'adult': False,
#    'backdrop_path': '/90ZZIoWQLLEXSVm0ik3eEQBinul.jpg',
#    'genre_ids': [28, 27, 53],
#    'id': 988233,
#    'original_language': 'en',
#    'original_title': 'Hex',
#    'overview': 'Following a mysterious disappearance on a jump, a group of skydivers experience paranormal occurrences that leave them fighting for their lives.',
#    'popularity': 2082.997,
#    'poster_path': '/xFJHb43ZAnnuiDztxZYsmyopweb.jpg',
#    'release_date': '2022-11-01',
#    'title': 'Hex',
#    'video': False,
#    'vote_average': 5.1,
#    'vote_count': 13},
#   {'adult': False,
#    'backdrop_path': '/xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg',
#    'genre_ids': [28, 12, 878],
#    'id': 505642,
#    'original_language': 'en',
#    'original_title': 'Black Panther: Wakanda Forever',
#    'overview': 'Queen Ramonda, Shuri, M’Baku, Okoye and the Dora Milaje fight to protect their nation from intervening world powers in the wake of King T’Challa’s death. As the Wakandans strive to embrace their next chapter, the heroes must band together with the help of War Dog Nakia and Everett Ross and forge a new path for the kingdom of Wakanda.',
#    'popularity': 1945.663,
#    'poster_path': '/ps2oKfhY6DL3alynlSqY97gHSsg.jpg',
#    'release_date': '2022-11-09',
#    'title': 'Black Panther: Wakanda Forever',
#    'video': False,
#    'vote_average': 7.5,
#    'vote_count': 1205},
#   {'adult': False,
#    'backdrop_path': '/707thQazLJiYLBhCrZlRoV05NNL.jpg',
#    'genre_ids': [28, 18, 53],
#    'id': 948276,
#    'original_language': 'fr',
#    'original_title': 'Balle perdue 2',
#    'overview': 'Having cleared his name, genius mechanic Lino has only one goal in mind: getting revenge on the corrupt cops who killed his brother and his mentor.',
#    'popularity': 1773.923,
#    'poster_path': '/uAeZI1JJbLPq7Bu5dziH7emHeu7.jpg',
#    'release_date': '2022-11-10',
#    'title': 'Lost Bullet 2',
#    'video': False,
#    'vote_average': 6.6,
#    'vote_count': 146},
#   {'adult': False,
#    'backdrop_path': '/jCY35GkjwWUmoPO9EV1lWL6kuyj.jpg',
#    'genre_ids': [28, 12, 53],
#    'id': 855440,
#    'original_language': 'es',
#    'original_title': 'Polar',
#    'overview': 'MG, a policewoman who has been expelled from the Corps due to the problems with alcohol and drugs that she has had since the loss of her son, receives a call from a man asking her to look for Macarena Gómez, a popular TV actress.',
#    'popularity': 1731.526,
#    'poster_path': '/efuKHH9LqBZB67AS87kprLgaYO8.jpg',
#    'release_date': '2022-10-26',
#    'title': 'Polar',
#    'video': False,
#    'vote_average': 7.5,
#    'vote_count': 2},
#   {'adult': False,
#    'backdrop_path': '/vmDa8HijINCAFYKqsMz0YM3sVyE.jpg',
#    'genre_ids': [80, 28, 53],
#    'id': 747803,
#    'original_language': 'en',
#    'original_title': 'One Way',
#    'overview': 'On the run with a bag full of cash after a robbing his former crime boss—and a potentially fatal wound—Freddy slips onto a bus headed into the unrelenting California desert. With his life slipping through his fingers, Freddy is left with very few choices to survive.',
#    'popularity': 1708.892,
#    'poster_path': '/uQCxOziq79P3wDsRwQhhkhQyDsJ.jpg',
#    'release_date': '2022-09-02',
#    'title': 'One Way',
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 21},
#   {'adult': False,
#    'backdrop_path': '/8Tr79lfoCkOYRg8SYwWit4OoQLi.jpg',
#    'genre_ids': [878, 28],
#    'id': 872177,
#    'original_language': 'en',
#    'original_title': 'Corrective Measures',
#    'overview': "Set in San Tiburon, the world's most dangerous maximum-security penitentiary and home to the world's most treacherous superpowered criminals, where tensions among the inmates and staff heighten, leading to anarchy that engulfs the prison and order is turned upside down.",
#    'popularity': 1555.835,
#    'poster_path': '/aHFq9NMhavOL0jtQvmHQ1c5e0ya.jpg',
#    'release_date': '2022-04-29',
#    'title': 'Corrective Measures',
#    'video': False,
#    'vote_average': 5.1,
#    'vote_count': 35},
#   {'adult': False,
#    'backdrop_path': '/sP1ShE4BGLkHSRqG9ZeGHg6C76t.jpg',
#    'genre_ids': [53, 80],
#    'id': 934641,
#    'original_language': 'en',
#    'original_title': 'The Minute You Wake Up Dead',
#    'overview': 'A stockbroker in a small southern town gets embroiled in an insurance scam with a next-door neighbor that leads to multiple murders when a host of other people want in on the plot. Sheriff Thurmond Fowler, the by-the-book town sheriff for over four decades, works earnestly to try and unravel the town’s mystery and winds up getting more than he bargained for.',
#    'popularity': 1778.464,
#    'poster_path': '/pUPwTbnAqfm95BZjNBnMMf39ChT.jpg',
#    'release_date': '2022-11-04',
#    'title': 'The Minute You Wake Up Dead',
#    'video': False,
#    'vote_average': 4.9,
#    'vote_count': 21},
#   {'adult': False,
#    'backdrop_path': '/rfnmMYuZ6EKOBvQLp2wqP21v7sI.jpg',
#    'genre_ids': [35, 878, 12],
#    'id': 774752,
#    'original_language': 'en',
#    'original_title': 'The Guardians of the Galaxy Holiday Special',
#    'overview': 'On a mission to make Christmas unforgettable for Quill, the Guardians head to Earth in search of the perfect present.',
#    'popularity': 1585.965,
#    'poster_path': '/8dqXyslZ2hv49Oiob9UjlGSHSTR.jpg',
#    'release_date': '2022-11-25',
#    'title': 'The Guardians of the Galaxy Holiday Special',
#    'video': False,
#    'vote_average': 7.5,
#    'vote_count': 599},
#   {'adult': False,
#    'backdrop_path': '/c1bz69r0v065TGFA5nqBiKzPDys.jpg',
#    'genre_ids': [35, 10751, 10402],
#    'id': 830784,
#    'original_language': 'en',
#    'original_title': 'Lyle, Lyle, Crocodile',
#    'overview': 'When the Primm family moves to New York City, their young son Josh struggles to adapt to his new school and new friends. All of that changes when he discovers Lyle — a singing crocodile who loves baths, caviar and great music — living in the attic of his new home. But when Lyle’s existence is threatened by evil neighbor Mr. Grumps, the Primms must band together to show the world that family can come from the most unexpected places.',
#    'popularity': 1385.693,
#    'poster_path': '/irIS5Tn3TXjNi1R9BpWvGAN4CZ1.jpg',
#    'release_date': '2022-10-07',
#    'title': 'Lyle, Lyle, Crocodile',
#    'video': False,
#    'vote_average': 7.8,
#    'vote_count': 136},
#   {'adult': False,
#    'backdrop_path': '/kpUre8wWSXn3D5RhrMttBZa6w1v.jpg',
#    'genre_ids': [35, 10751, 14],
#    'id': 338958,
#    'original_language': 'en',
#    'original_title': 'Disenchanted',
#    'overview': 'Disillusioned with life in the city, feeling out of place in suburbia, and frustrated that her happily ever after hasn’t been so easy to find, Giselle turns to the magic of Andalasia for help. Accidentally transforming the entire town into a real-life fairy tale and placing her family’s future happiness in jeopardy, she must race against time to reverse the spell and determine what happily ever after truly means to her and her family.',
#    'popularity': 1292.793,
#    'poster_path': '/4x3pt6hoLblBeHebUa4OyiVXFiM.jpg',
#    'release_date': '2022-11-16',
#    'title': 'Disenchanted',
#    'video': False,
#    'vote_average': 7.3,
#    'vote_count': 490},
#   {'adult': False,
#    'backdrop_path': '/olPXihyFeeNvnaD6IOBltgIV1FU.jpg',
#    'genre_ids': [27, 9648, 53],
#    'id': 882598,
#    'original_language': 'en',
#    'original_title': 'Smile',
#    'overview': "After witnessing a bizarre, traumatic incident involving a patient, Dr. Rose Cotter starts experiencing frightening occurrences that she can't explain. As an overwhelming terror begins taking over her life, Rose must confront her troubling past in order to survive and escape her horrifying new reality.",
#    'popularity': 1296.323,
#    'poster_path': '/aPqcQwu4VGEewPhagWNncDbJ9Xp.jpg',
#    'release_date': '2022-09-23',
#    'title': 'Smile',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 1040},
#   {'adult': False,
#    'backdrop_path': '/5aSvzECXrtABcIh7fZYkH2K6ttC.jpg',
#    'genre_ids': [28, 53, 80],
#    'id': 972313,
#    'original_language': 'en',
#    'original_title': 'Blowback',
#    'overview': "When a master thief is sabotaged during a bank heist and left for dead, he seeks revenge on his former crew one target at a time. Now, with the cops and the mob closing in, he's in the race of his life to reclaim an untold fortune in cryptocurrency from those who double-crossed him.",
#    'popularity': 1326.345,
#    'poster_path': '/fHQHC32dhom8u0OxC2hs2gYQh0M.jpg',
#    'release_date': '2022-06-17',
#    'title': 'Blowback',
#    'video': False,
#    'vote_average': 6.1,
#    'vote_count': 22},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [10749],
#    'id': 485470,
#    'original_language': 'ko',
#    'original_title': '착한 형수2',
#    'overview': "If you give it once, a good brother-in-law who gives everything generously will come!  At the house of her girlfriend Jin-kyung, who lives with pumice stone, her brother and his wife suddenly visit and the four of them live together. At first, Kyung-seok, who was burdened by his girlfriend's brother, began to keep his eyes on his wife, Yeon-su. A bold brother-in-law who walks around in no-bra and panties without hesitation even at his sister-in-law's house. Besides, from a certain moment, he starts to send a hand of temptation to Pyeong-seok first...",
#    'popularity': 909.281,
#    'poster_path': '/3pEs4hmeHvTAsmx09whEaPDOQpq.jpg',
#    'release_date': '2017-10-08',
#    'title': 'Nice Sister-In-Law 2',
#    'video': False,
#    'vote_average': 6,
#    'vote_count': 2},
#   {'adult': False,
#    'backdrop_path': '/eyiSLRh44SKKWIJ6bxWq8z1sscB.jpg',
#    'genre_ids': [53, 27, 80],
#    'id': 899294,
#    'original_language': 'en',
#    'original_title': 'Frank and Penelope',
#    'overview': 'A tale of love and violence when a man on his emotional last legs finds a savior seductively dancing in a run-down strip club. And a life most certainly headed off a cliff suddenly becomes redirected - as everything is now worth dying for.',
#    'popularity': 1102.491,
#    'poster_path': '/5NpXoAi3nEQkEgLO09nmotPfyNa.jpg',
#    'release_date': '2022-06-03',
#    'title': 'Frank and Penelope',
#    'video': False,
#    'vote_average': 7.8,
#    'vote_count': 44},
#   {'adult': False,
#    'backdrop_path': '/yNib9QAiyaopUJbaayKQ2xK7mYf.jpg',
#    'genre_ids': [18, 28, 10752],
#    'id': 966220,
#    'original_language': 'uk',
#    'original_title': 'Снайпер. Білий ворон',
#    'overview': 'Mykola is an eccentric pacifist who wants to be useful to humanity. When the war begins at Donbass, Mykola’s naive world is collapsing as the militants kill his pregnant wife and burn his home to the ground. Recovered, he makes a cardinal decision and gets enlisted in a sniper company. Having met his wife’s killers, he emotionally breaks down and arranges “sniper terror” for the enemy. He’s saved from a senseless death by his instructor who himself gets mortally wounded. The death of a friend leaves a “scar” and Mykola is ready to sacrifice his life.',
#    'popularity': 1097.152,
#    'poster_path': '/lZOODJzwuQo0etJJyBBZJOSdZcW.jpg',
#    'release_date': '2022-05-03',
#    'title': 'Sniper: The White Raven',
#    'video': False,
#    'vote_average': 7.7,
#    'vote_count': 146}],
#  'total_pages': 36188,
#  'total_results': 723758}

# %%
results_1 = response["results"]
# len(results)

tmdb_1_df = pd.DataFrame(results_1)
tmdb_1_df
# Out:
#     adult                     backdrop_path           genre_ids       id  \
# 0   False  /bQXAqRx2Fgc46uCVWgoPz5L5Dtr.jpg       [28, 14, 878]   436270
# 1   False  /7zQJYV02yehWrQN6NjKsBorqUUS.jpg        [28, 18, 36]   724495
# 2   False  /au4HUSWDRadIcl9CqySlw1kJMfo.jpg        [80, 28, 53]   829799
# 3   False  /sUuzl04qNIYsnwCLQpZ2RSvXA1V.jpg        [35, 28, 53]   792775
# 4   False  /kmzppWh7ljL6K9fXW72bPN3gKwu.jpg    [14, 28, 35, 80]  1013860
# 5   False  /90ZZIoWQLLEXSVm0ik3eEQBinul.jpg        [28, 27, 53]   988233
# 6   False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg       [28, 12, 878]   505642
# 7   False  /707thQazLJiYLBhCrZlRoV05NNL.jpg        [28, 18, 53]   948276
# 8   False  /jCY35GkjwWUmoPO9EV1lWL6kuyj.jpg        [28, 12, 53]   855440
# 9   False  /vmDa8HijINCAFYKqsMz0YM3sVyE.jpg        [80, 28, 53]   747803
# 10  False  /8Tr79lfoCkOYRg8SYwWit4OoQLi.jpg           [878, 28]   872177
# 11  False  /sP1ShE4BGLkHSRqG9ZeGHg6C76t.jpg            [53, 80]   934641
# 12  False  /rfnmMYuZ6EKOBvQLp2wqP21v7sI.jpg       [35, 878, 12]   774752
# 13  False  /c1bz69r0v065TGFA5nqBiKzPDys.jpg  [35, 10751, 10402]   830784
# 14  False  /kpUre8wWSXn3D5RhrMttBZa6w1v.jpg     [35, 10751, 14]   338958
# 15  False  /olPXihyFeeNvnaD6IOBltgIV1FU.jpg      [27, 9648, 53]   882598
# 16  False  /5aSvzECXrtABcIh7fZYkH2K6ttC.jpg        [28, 53, 80]   972313
# 17  False                              None             [10749]   485470
# 18  False  /eyiSLRh44SKKWIJ6bxWq8z1sscB.jpg        [53, 27, 80]   899294
# 19  False  /yNib9QAiyaopUJbaayKQ2xK7mYf.jpg     [18, 28, 10752]   966220
#
#    original_language                               original_title  \
# 0                 en                                   Black Adam
# 1                 en                               The Woman King
# 2                 en                                Paradise City
# 3                 is                                   Leynilögga
# 4                 en               R.I.P.D. 2: Rise of the Damned
# 5                 en                                          Hex
# 6                 en               Black Panther: Wakanda Forever
# 7                 fr                               Balle perdue 2
# 8                 es                                        Polar
# 9                 en                                      One Way
# 10                en                          Corrective Measures
# 11                en                  The Minute You Wake Up Dead
# 12                en  The Guardians of the Galaxy Holiday Special
# 13                en                        Lyle, Lyle, Crocodile
# 14                en                                 Disenchanted
# 15                en                                        Smile
# 16                en                                     Blowback
# 17                ko                                       착한 형수2
# 18                en                           Frank and Penelope
# 19                uk                         Снайпер. Білий ворон
#
#                                              overview  popularity  \
# 0   Nearly 5,000 years after he was bestowed with ...    8198.814
# 1   The story of the Agojie, the all-female unit o...    4662.739
# 2   Renegade bounty hunter Ryan Swan must carve hi...    2645.370
# 3   When Bússi, Iceland's toughest cop, is forced ...    2308.284
# 4   When Sheriff Roy Pulsipher finds himself in th...    2530.159
# 5   Following a mysterious disappearance on a jump...    2082.997
# 6   Queen Ramonda, Shuri, M’Baku, Okoye and the Do...    1945.663
# 7   Having cleared his name, genius mechanic Lino ...    1773.923
# 8   MG, a policewoman who has been expelled from t...    1731.526
# 9   On the run with a bag full of cash after a rob...    1708.892
# 10  Set in San Tiburon, the world's most dangerous...    1555.835
# 11  A stockbroker in a small southern town gets em...    1778.464
# 12  On a mission to make Christmas unforgettable f...    1585.965
# 13  When the Primm family moves to New York City, ...    1385.693
# 14  Disillusioned with life in the city, feeling o...    1292.793
# 15  After witnessing a bizarre, traumatic incident...    1296.323
# 16  When a master thief is sabotaged during a bank...    1326.345
# 17  If you give it once, a good brother-in-law who...     909.281
# 18  A tale of love and violence when a man on his ...    1102.491
# 19  Mykola is an eccentric pacifist who wants to b...    1097.152
#
#                          poster_path release_date  \
# 0   /pFlaoHTZeyNkG83vxsAJiGzfSsa.jpg   2022-10-19
# 1   /438QXt1E3WJWb3PqNniK0tAE5c1.jpg   2022-09-15
# 2   /xdmmd437QdjcCls8yCQxrH5YYM4.jpg   2022-11-11
# 3   /jnWyZsaCl3Ke6u6ReSmBRO8S1rX.jpg   2022-05-23
# 4   /g4yJTzMtOBUTAR2Qnmj8TYIcFVq.jpg   2022-11-15
# 5   /xFJHb43ZAnnuiDztxZYsmyopweb.jpg   2022-11-01
# 6   /ps2oKfhY6DL3alynlSqY97gHSsg.jpg   2022-11-09
# 7   /uAeZI1JJbLPq7Bu5dziH7emHeu7.jpg   2022-11-10
# 8   /efuKHH9LqBZB67AS87kprLgaYO8.jpg   2022-10-26
# 9   /uQCxOziq79P3wDsRwQhhkhQyDsJ.jpg   2022-09-02
# 10  /aHFq9NMhavOL0jtQvmHQ1c5e0ya.jpg   2022-04-29
# 11  /pUPwTbnAqfm95BZjNBnMMf39ChT.jpg   2022-11-04
# 12  /8dqXyslZ2hv49Oiob9UjlGSHSTR.jpg   2022-11-25
# 13  /irIS5Tn3TXjNi1R9BpWvGAN4CZ1.jpg   2022-10-07
# 14  /4x3pt6hoLblBeHebUa4OyiVXFiM.jpg   2022-11-16
# 15  /aPqcQwu4VGEewPhagWNncDbJ9Xp.jpg   2022-09-23
# 16  /fHQHC32dhom8u0OxC2hs2gYQh0M.jpg   2022-06-17
# 17  /3pEs4hmeHvTAsmx09whEaPDOQpq.jpg   2017-10-08
# 18  /5NpXoAi3nEQkEgLO09nmotPfyNa.jpg   2022-06-03
# 19  /lZOODJzwuQo0etJJyBBZJOSdZcW.jpg   2022-05-03
#
#                                           title  video  vote_average  \
# 0                                    Black Adam  False           7.3
# 1                                The Woman King  False           7.9
# 2                                 Paradise City  False           6.4
# 3                                    Cop Secret  False           6.3
# 4                R.I.P.D. 2: Rise of the Damned  False           6.7
# 5                                           Hex  False           5.1
# 6                Black Panther: Wakanda Forever  False           7.5
# 7                                 Lost Bullet 2  False           6.6
# 8                                         Polar  False           7.5
# 9                                       One Way  False           6.4
# 10                          Corrective Measures  False           5.1
# 11                  The Minute You Wake Up Dead  False           4.9
# 12  The Guardians of the Galaxy Holiday Special  False           7.5
# 13                        Lyle, Lyle, Crocodile  False           7.8
# 14                                 Disenchanted  False           7.3
# 15                                        Smile  False           6.8
# 16                                     Blowback  False           6.1
# 17                         Nice Sister-In-Law 2  False           6.0
# 18                           Frank and Penelope  False           7.8
# 19                      Sniper: The White Raven  False           7.7
#
#     vote_count
# 0         2493
# 1          611
# 2           40
# 3           33
# 4          206
# 5           13
# 6         1205
# 7          146
# 8            2
# 9           21
# 10          35
# 11          21
# 12         599
# 13         136
# 14         490
# 15        1040
# 16          22
# 17           2
# 18          44
# 19         146

# %%
tmdb_1_df = tmdb_1_df.set_index('id')
tmdb_1_df
# Out:
#          adult                     backdrop_path           genre_ids  \
# id
# 436270   False  /bQXAqRx2Fgc46uCVWgoPz5L5Dtr.jpg       [28, 14, 878]
# 724495   False  /7zQJYV02yehWrQN6NjKsBorqUUS.jpg        [28, 18, 36]
# 829799   False  /au4HUSWDRadIcl9CqySlw1kJMfo.jpg        [80, 28, 53]
# 792775   False  /sUuzl04qNIYsnwCLQpZ2RSvXA1V.jpg        [35, 28, 53]
# 1013860  False  /kmzppWh7ljL6K9fXW72bPN3gKwu.jpg    [14, 28, 35, 80]
# 988233   False  /90ZZIoWQLLEXSVm0ik3eEQBinul.jpg        [28, 27, 53]
# 505642   False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg       [28, 12, 878]
# 948276   False  /707thQazLJiYLBhCrZlRoV05NNL.jpg        [28, 18, 53]
# 855440   False  /jCY35GkjwWUmoPO9EV1lWL6kuyj.jpg        [28, 12, 53]
# 747803   False  /vmDa8HijINCAFYKqsMz0YM3sVyE.jpg        [80, 28, 53]
# 872177   False  /8Tr79lfoCkOYRg8SYwWit4OoQLi.jpg           [878, 28]
# 934641   False  /sP1ShE4BGLkHSRqG9ZeGHg6C76t.jpg            [53, 80]
# 774752   False  /rfnmMYuZ6EKOBvQLp2wqP21v7sI.jpg       [35, 878, 12]
# 830784   False  /c1bz69r0v065TGFA5nqBiKzPDys.jpg  [35, 10751, 10402]
# 338958   False  /kpUre8wWSXn3D5RhrMttBZa6w1v.jpg     [35, 10751, 14]
# 882598   False  /olPXihyFeeNvnaD6IOBltgIV1FU.jpg      [27, 9648, 53]
# 972313   False  /5aSvzECXrtABcIh7fZYkH2K6ttC.jpg        [28, 53, 80]
# 485470   False                              None             [10749]
# 899294   False  /eyiSLRh44SKKWIJ6bxWq8z1sscB.jpg        [53, 27, 80]
# 966220   False  /yNib9QAiyaopUJbaayKQ2xK7mYf.jpg     [18, 28, 10752]
#
#         original_language                               original_title  \
# id
# 436270                 en                                   Black Adam
# 724495                 en                               The Woman King
# 829799                 en                                Paradise City
# 792775                 is                                   Leynilögga
# 1013860                en               R.I.P.D. 2: Rise of the Damned
# 988233                 en                                          Hex
# 505642                 en               Black Panther: Wakanda Forever
# 948276                 fr                               Balle perdue 2
# 855440                 es                                        Polar
# 747803                 en                                      One Way
# 872177                 en                          Corrective Measures
# 934641                 en                  The Minute You Wake Up Dead
# 774752                 en  The Guardians of the Galaxy Holiday Special
# 830784                 en                        Lyle, Lyle, Crocodile
# 338958                 en                                 Disenchanted
# 882598                 en                                        Smile
# 972313                 en                                     Blowback
# 485470                 ko                                       착한 형수2
# 899294                 en                           Frank and Penelope
# 966220                 uk                         Снайпер. Білий ворон
#
#                                                   overview  popularity  \
# id
# 436270   Nearly 5,000 years after he was bestowed with ...    8198.814
# 724495   The story of the Agojie, the all-female unit o...    4662.739
# 829799   Renegade bounty hunter Ryan Swan must carve hi...    2645.370
# 792775   When Bússi, Iceland's toughest cop, is forced ...    2308.284
# 1013860  When Sheriff Roy Pulsipher finds himself in th...    2530.159
# 988233   Following a mysterious disappearance on a jump...    2082.997
# 505642   Queen Ramonda, Shuri, M’Baku, Okoye and the Do...    1945.663
# 948276   Having cleared his name, genius mechanic Lino ...    1773.923
# 855440   MG, a policewoman who has been expelled from t...    1731.526
# 747803   On the run with a bag full of cash after a rob...    1708.892
# 872177   Set in San Tiburon, the world's most dangerous...    1555.835
# 934641   A stockbroker in a small southern town gets em...    1778.464
# 774752   On a mission to make Christmas unforgettable f...    1585.965
# 830784   When the Primm family moves to New York City, ...    1385.693
# 338958   Disillusioned with life in the city, feeling o...    1292.793
# 882598   After witnessing a bizarre, traumatic incident...    1296.323
# 972313   When a master thief is sabotaged during a bank...    1326.345
# 485470   If you give it once, a good brother-in-law who...     909.281
# 899294   A tale of love and violence when a man on his ...    1102.491
# 966220   Mykola is an eccentric pacifist who wants to b...    1097.152
#
#                               poster_path release_date  \
# id
# 436270   /pFlaoHTZeyNkG83vxsAJiGzfSsa.jpg   2022-10-19
# 724495   /438QXt1E3WJWb3PqNniK0tAE5c1.jpg   2022-09-15
# 829799   /xdmmd437QdjcCls8yCQxrH5YYM4.jpg   2022-11-11
# 792775   /jnWyZsaCl3Ke6u6ReSmBRO8S1rX.jpg   2022-05-23
# 1013860  /g4yJTzMtOBUTAR2Qnmj8TYIcFVq.jpg   2022-11-15
# 988233   /xFJHb43ZAnnuiDztxZYsmyopweb.jpg   2022-11-01
# 505642   /ps2oKfhY6DL3alynlSqY97gHSsg.jpg   2022-11-09
# 948276   /uAeZI1JJbLPq7Bu5dziH7emHeu7.jpg   2022-11-10
# 855440   /efuKHH9LqBZB67AS87kprLgaYO8.jpg   2022-10-26
# 747803   /uQCxOziq79P3wDsRwQhhkhQyDsJ.jpg   2022-09-02
# 872177   /aHFq9NMhavOL0jtQvmHQ1c5e0ya.jpg   2022-04-29
# 934641   /pUPwTbnAqfm95BZjNBnMMf39ChT.jpg   2022-11-04
# 774752   /8dqXyslZ2hv49Oiob9UjlGSHSTR.jpg   2022-11-25
# 830784   /irIS5Tn3TXjNi1R9BpWvGAN4CZ1.jpg   2022-10-07
# 338958   /4x3pt6hoLblBeHebUa4OyiVXFiM.jpg   2022-11-16
# 882598   /aPqcQwu4VGEewPhagWNncDbJ9Xp.jpg   2022-09-23
# 972313   /fHQHC32dhom8u0OxC2hs2gYQh0M.jpg   2022-06-17
# 485470   /3pEs4hmeHvTAsmx09whEaPDOQpq.jpg   2017-10-08
# 899294   /5NpXoAi3nEQkEgLO09nmotPfyNa.jpg   2022-06-03
# 966220   /lZOODJzwuQo0etJJyBBZJOSdZcW.jpg   2022-05-03
#
#                                                title  video  vote_average  \
# id
# 436270                                    Black Adam  False           7.3
# 724495                                The Woman King  False           7.9
# 829799                                 Paradise City  False           6.4
# 792775                                    Cop Secret  False           6.3
# 1013860               R.I.P.D. 2: Rise of the Damned  False           6.7
# 988233                                           Hex  False           5.1
# 505642                Black Panther: Wakanda Forever  False           7.5
# 948276                                 Lost Bullet 2  False           6.6
# 855440                                         Polar  False           7.5
# 747803                                       One Way  False           6.4
# 872177                           Corrective Measures  False           5.1
# 934641                   The Minute You Wake Up Dead  False           4.9
# 774752   The Guardians of the Galaxy Holiday Special  False           7.5
# 830784                         Lyle, Lyle, Crocodile  False           7.8
# 338958                                  Disenchanted  False           7.3
# 882598                                         Smile  False           6.8
# 972313                                      Blowback  False           6.1
# 485470                          Nice Sister-In-Law 2  False           6.0
# 899294                            Frank and Penelope  False           7.8
# 966220                       Sniper: The White Raven  False           7.7
#
#          vote_count
# id
# 436270         2493
# 724495          611
# 829799           40
# 792775           33
# 1013860         206
# 988233           13
# 505642         1205
# 948276          146
# 855440            2
# 747803           21
# 872177           35
# 934641           21
# 774752          599
# 830784          136
# 338958          490
# 882598         1040
# 972313           22
# 485470            2
# 899294           44
# 966220          146

# %%
tmdb_1_df.rename(columns={'popularity':'tmdb_popularity', 'overview':'description', 'vote_average':'tmdb_score' }, inplace = True)
tmdb_1_df
# Out:
#          adult                     backdrop_path           genre_ids  \
# id
# 436270   False  /bQXAqRx2Fgc46uCVWgoPz5L5Dtr.jpg       [28, 14, 878]
# 724495   False  /7zQJYV02yehWrQN6NjKsBorqUUS.jpg        [28, 18, 36]
# 829799   False  /au4HUSWDRadIcl9CqySlw1kJMfo.jpg        [80, 28, 53]
# 792775   False  /sUuzl04qNIYsnwCLQpZ2RSvXA1V.jpg        [35, 28, 53]
# 1013860  False  /kmzppWh7ljL6K9fXW72bPN3gKwu.jpg    [14, 28, 35, 80]
# 988233   False  /90ZZIoWQLLEXSVm0ik3eEQBinul.jpg        [28, 27, 53]
# 505642   False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg       [28, 12, 878]
# 948276   False  /707thQazLJiYLBhCrZlRoV05NNL.jpg        [28, 18, 53]
# 855440   False  /jCY35GkjwWUmoPO9EV1lWL6kuyj.jpg        [28, 12, 53]
# 747803   False  /vmDa8HijINCAFYKqsMz0YM3sVyE.jpg        [80, 28, 53]
# 872177   False  /8Tr79lfoCkOYRg8SYwWit4OoQLi.jpg           [878, 28]
# 934641   False  /sP1ShE4BGLkHSRqG9ZeGHg6C76t.jpg            [53, 80]
# 774752   False  /rfnmMYuZ6EKOBvQLp2wqP21v7sI.jpg       [35, 878, 12]
# 830784   False  /c1bz69r0v065TGFA5nqBiKzPDys.jpg  [35, 10751, 10402]
# 338958   False  /kpUre8wWSXn3D5RhrMttBZa6w1v.jpg     [35, 10751, 14]
# 882598   False  /olPXihyFeeNvnaD6IOBltgIV1FU.jpg      [27, 9648, 53]
# 972313   False  /5aSvzECXrtABcIh7fZYkH2K6ttC.jpg        [28, 53, 80]
# 485470   False                              None             [10749]
# 899294   False  /eyiSLRh44SKKWIJ6bxWq8z1sscB.jpg        [53, 27, 80]
# 966220   False  /yNib9QAiyaopUJbaayKQ2xK7mYf.jpg     [18, 28, 10752]
#
#         original_language                               original_title  \
# id
# 436270                 en                                   Black Adam
# 724495                 en                               The Woman King
# 829799                 en                                Paradise City
# 792775                 is                                   Leynilögga
# 1013860                en               R.I.P.D. 2: Rise of the Damned
# 988233                 en                                          Hex
# 505642                 en               Black Panther: Wakanda Forever
# 948276                 fr                               Balle perdue 2
# 855440                 es                                        Polar
# 747803                 en                                      One Way
# 872177                 en                          Corrective Measures
# 934641                 en                  The Minute You Wake Up Dead
# 774752                 en  The Guardians of the Galaxy Holiday Special
# 830784                 en                        Lyle, Lyle, Crocodile
# 338958                 en                                 Disenchanted
# 882598                 en                                        Smile
# 972313                 en                                     Blowback
# 485470                 ko                                       착한 형수2
# 899294                 en                           Frank and Penelope
# 966220                 uk                         Снайпер. Білий ворон
#
#                                                description  tmdb_popularity  \
# id
# 436270   Nearly 5,000 years after he was bestowed with ...         8198.814
# 724495   The story of the Agojie, the all-female unit o...         4662.739
# 829799   Renegade bounty hunter Ryan Swan must carve hi...         2645.370
# 792775   When Bússi, Iceland's toughest cop, is forced ...         2308.284
# 1013860  When Sheriff Roy Pulsipher finds himself in th...         2530.159
# 988233   Following a mysterious disappearance on a jump...         2082.997
# 505642   Queen Ramonda, Shuri, M’Baku, Okoye and the Do...         1945.663
# 948276   Having cleared his name, genius mechanic Lino ...         1773.923
# 855440   MG, a policewoman who has been expelled from t...         1731.526
# 747803   On the run with a bag full of cash after a rob...         1708.892
# 872177   Set in San Tiburon, the world's most dangerous...         1555.835
# 934641   A stockbroker in a small southern town gets em...         1778.464
# 774752   On a mission to make Christmas unforgettable f...         1585.965
# 830784   When the Primm family moves to New York City, ...         1385.693
# 338958   Disillusioned with life in the city, feeling o...         1292.793
# 882598   After witnessing a bizarre, traumatic incident...         1296.323
# 972313   When a master thief is sabotaged during a bank...         1326.345
# 485470   If you give it once, a good brother-in-law who...          909.281
# 899294   A tale of love and violence when a man on his ...         1102.491
# 966220   Mykola is an eccentric pacifist who wants to b...         1097.152
#
#                               poster_path release_date  \
# id
# 436270   /pFlaoHTZeyNkG83vxsAJiGzfSsa.jpg   2022-10-19
# 724495   /438QXt1E3WJWb3PqNniK0tAE5c1.jpg   2022-09-15
# 829799   /xdmmd437QdjcCls8yCQxrH5YYM4.jpg   2022-11-11
# 792775   /jnWyZsaCl3Ke6u6ReSmBRO8S1rX.jpg   2022-05-23
# 1013860  /g4yJTzMtOBUTAR2Qnmj8TYIcFVq.jpg   2022-11-15
# 988233   /xFJHb43ZAnnuiDztxZYsmyopweb.jpg   2022-11-01
# 505642   /ps2oKfhY6DL3alynlSqY97gHSsg.jpg   2022-11-09
# 948276   /uAeZI1JJbLPq7Bu5dziH7emHeu7.jpg   2022-11-10
# 855440   /efuKHH9LqBZB67AS87kprLgaYO8.jpg   2022-10-26
# 747803   /uQCxOziq79P3wDsRwQhhkhQyDsJ.jpg   2022-09-02
# 872177   /aHFq9NMhavOL0jtQvmHQ1c5e0ya.jpg   2022-04-29
# 934641   /pUPwTbnAqfm95BZjNBnMMf39ChT.jpg   2022-11-04
# 774752   /8dqXyslZ2hv49Oiob9UjlGSHSTR.jpg   2022-11-25
# 830784   /irIS5Tn3TXjNi1R9BpWvGAN4CZ1.jpg   2022-10-07
# 338958   /4x3pt6hoLblBeHebUa4OyiVXFiM.jpg   2022-11-16
# 882598   /aPqcQwu4VGEewPhagWNncDbJ9Xp.jpg   2022-09-23
# 972313   /fHQHC32dhom8u0OxC2hs2gYQh0M.jpg   2022-06-17
# 485470   /3pEs4hmeHvTAsmx09whEaPDOQpq.jpg   2017-10-08
# 899294   /5NpXoAi3nEQkEgLO09nmotPfyNa.jpg   2022-06-03
# 966220   /lZOODJzwuQo0etJJyBBZJOSdZcW.jpg   2022-05-03
#
#                                                title  video  tmdb_score  \
# id
# 436270                                    Black Adam  False         7.3
# 724495                                The Woman King  False         7.9
# 829799                                 Paradise City  False         6.4
# 792775                                    Cop Secret  False         6.3
# 1013860               R.I.P.D. 2: Rise of the Damned  False         6.7
# 988233                                           Hex  False         5.1
# 505642                Black Panther: Wakanda Forever  False         7.5
# 948276                                 Lost Bullet 2  False         6.6
# 855440                                         Polar  False         7.5
# 747803                                       One Way  False         6.4
# 872177                           Corrective Measures  False         5.1
# 934641                   The Minute You Wake Up Dead  False         4.9
# 774752   The Guardians of the Galaxy Holiday Special  False         7.5
# 830784                         Lyle, Lyle, Crocodile  False         7.8
# 338958                                  Disenchanted  False         7.3
# 882598                                         Smile  False         6.8
# 972313                                      Blowback  False         6.1
# 485470                          Nice Sister-In-Law 2  False         6.0
# 899294                            Frank and Penelope  False         7.8
# 966220                       Sniper: The White Raven  False         7.7
#
#          vote_count
# id
# 436270         2493
# 724495          611
# 829799           40
# 792775           33
# 1013860         206
# 988233           13
# 505642         1205
# 948276          146
# 855440            2
# 747803           21
# 872177           35
# 934641           21
# 774752          599
# 830784          136
# 338958          490
# 882598         1040
# 972313           22
# 485470            2
# 899294           44
# 966220          146

# %%
# Rename the columns to match the disney and netflix column names
tmdb_1_df.to_sql(name='tmdb', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from tmdb', con=engine).head()
